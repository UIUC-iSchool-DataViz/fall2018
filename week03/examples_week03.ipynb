# %%
# %matplotlib inline

# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# %%
df = pd.read_csv("/home/shared/sp18-is590dv/data/IL_Building_Inventory.csv",
           na_values = {'Year Acquired': 0, 'Year Constructed': 0, 'Square Footage': 0})

# %%
df.groupby("Year Acquired")

# %%
df.groupby("Year Acquired")["Square Footage"].sum()
# Out:
# Year Acquired
# 1753.0       1200.0
# 1802.0       4440.0
# 1810.0       4033.0
# 1832.0     120000.0
# 1837.0      10302.0
# 1838.0       2010.0
# 1839.0      11752.0
# 1840.0      36918.0
# 1841.0       3256.0
# 1843.0        900.0
# 1844.0       4088.0
# 1845.0      65846.0
# 1848.0      21292.0
# 1850.0       2267.0
# 1853.0     255000.0
# 1854.0       2140.0
# 1855.0      66154.0
# 1856.0        750.0
# 1857.0      18124.0
# 1858.0      22367.0
# 1859.0       4847.0
# 1860.0      27417.0
# 1863.0      15795.0
# 1865.0     223494.0
# 1867.0       2700.0
# 1870.0       2864.0
# 1871.0       6403.0
# 1872.0      14900.0
# 1873.0      11000.0
# 1874.0       6600.0
#             ...
# 1990.0    2209048.0
# 1991.0    1653847.0
# 1992.0     900610.0
# 1993.0     351998.0
# 1994.0     435657.0
# 1995.0     877396.0
# 1996.0    1351591.0
# 1997.0    1110664.0
# 1998.0     731394.0
# 1999.0     364417.0
# 2000.0    1248787.0
# 2001.0    1329954.0
# 2002.0    1036110.0
# 2003.0    1041629.0
# 2004.0     575251.0
# 2005.0    1494411.0
# 2006.0     621710.0
# 2007.0     995526.0
# 2008.0     160223.0
# 2009.0     259724.0
# 2010.0     378725.0
# 2011.0     152953.0
# 2012.0     250113.0
# 2013.0     391485.0
# 2014.0     664298.0
# 2015.0     305093.0
# 2016.0     304839.0
# 2017.0       6720.0
# 2018.0      17160.0
# 2019.0       1520.0
# Name: Square Footage, Length: 171, dtype: float64

# %%
stats = df.groupby("Year Acquired")["Square Footage"].describe()

# %%
stats.loc[2010]
# Out:
# count        22.000000
# mean      17214.772727
# std       34147.046575
# min          24.000000
# 25%         495.000000
# 50%        4000.000000
# 75%       10937.750000
# max      148183.000000
# Name: 2010.0, dtype: float64

# %%
stats.iloc[0]
# Out:
# count       1.0
# mean     1200.0
# std         NaN
# min      1200.0
# 25%      1200.0
# 50%      1200.0
# 75%      1200.0
# max      1200.0
# Name: 1753.0, dtype: float64

# %%
plt.plot(stats["max"], marker='.', linewidth = 1.0)
plt.xlabel("Year")
plt.ylabel("Square Footage")
plt.yscale("log")

# %%
plt.plot(stats["min"], marker='.', linewidth = 1.0)
plt.xlabel("Year")
plt.ylabel("Square Footage")
plt.yscale("log")

# %%
plt.plot(stats["max"], marker='.', linewidth = 1.0, label = "Max")
plt.plot(stats["min"], marker='.', linewidth = 1.0, label = "Min")
plt.fill_between(stats.index, stats["min"], stats["max"], color = "#dddddd")
plt.xlabel("Year")
plt.ylabel("Square Footage")
plt.yscale("log")
plt.legend()

# %%
plt.rcParams["figure.dpi"] = 200

# %%
plt.plot(stats["max"], marker='.', linewidth = 1.0, label = "Max")
plt.plot(stats["min"], marker='.', linewidth = 1.0, label = "Min")
plt.fill_between(stats.index, stats["min"], stats["max"], color = "#dddddd")
plt.xlabel("Year")
plt.ylabel("Square Footage")
plt.yscale("log")
plt.legend()

# %%
with plt.style.context("ggplot"):
    plt.plot(stats["max"], marker='.', linewidth = 1.0, label = "Max")
    plt.plot(stats["min"], marker='.', linewidth = 1.0, label = "Min")
    plt.fill_between(stats.index, stats["min"], stats["max"], color = "#aaaaaa")
    plt.xlabel("Year")
    plt.ylabel("Square Footage")
    plt.yscale("log")
    plt.legend()

# %%
plt.style.available
# Out:
# ['seaborn-ticks',
#  'fast',
#  'seaborn-darkgrid',
#  'seaborn-talk',
#  'seaborn',
#  'seaborn-dark-palette',
#  'seaborn-whitegrid',
#  'bmh',
#  'seaborn-notebook',
#  'Solarize_Light2',
#  'ggplot',
#  'seaborn-paper',
#  '_classic_test',
#  'seaborn-bright',
#  'seaborn-pastel',
#  'seaborn-colorblind',
#  'seaborn-dark',
#  'seaborn-poster',
#  'classic',
#  'grayscale',
#  'fivethirtyeight',
#  'seaborn-muted',
#  'seaborn-deep',
#  'seaborn-white',
#  'dark_background']

# %%
import ipywidgets

# %%
@ipywidgets.interact(style = plt.style.available)
def make_plot(style):
    with plt.style.context(style):
        plt.plot(stats["max"], marker='.', linewidth = 1.0, label = "Max")
        plt.plot(stats["min"], marker='.', linewidth = 1.0, label = "Min")
        plt.fill_between(stats.index, stats["min"], stats["max"], color = "#aaaaaa")
        plt.xlabel("Year")
        plt.ylabel("Square Footage")
        plt.yscale("log")
        plt.legend()
# Out:
# interactive(children=(Dropdown(description='style', options=('seaborn-ticks', 'fast', 'seaborn-darkgrid', 'seaborn-talk', 'seaborn', 'seaborn-dark-palette', 'seaborn-whitegrid', 'bmh', 'seaborn-notebook', 'Solarize_Light2', 'ggplot', 'seaborn-paper', '_classic_test', 'seaborn-bright', 'seaborn-pastel', 'seaborn-colorblind', 'seaborn-dark', 'seaborn-poster', 'classic', 'grayscale', 'fivethirtyeight', 'seaborn-muted', 'seaborn-deep', 'seaborn-white', 'dark_background'), value='seaborn-ticks'), Output()), _dom_classes=('widget-interact',))

# %%
with plt.style.context("ggplot"):
    plt.plot(stats["max"], marker='.', linewidth = 1.0, label = "Max")
    plt.plot(stats["min"], marker='.', linewidth = 1.0, label = "Min")
    plt.fill_between(stats.index, stats["min"], stats["max"], color = "#aaaaaa")
    plt.xlabel("Year")
    plt.ylabel("Square Footage")
    plt.yscale("log")
    plt.legend()

# %%
plt.plot(stats["max"], marker='.', linewidth = 1.0, label = "Max")
plt.plot(stats["min"], marker='.', linewidth = 1.0, label = "Min")
plt.fill_between(stats.index, stats["min"], stats["max"], color = "#aaaaaa")
plt.xlabel("Year")
plt.ylabel("Square Footage")
plt.yscale("log")
plt.plot([1818, 1818], [10, 10**6], color = 'black', linewidth = 2.0)
plt.legend()

# %%
import matplotlib.transforms as mpt

# %%
plt.plot(stats["max"], marker='.', linewidth = 1.0, label = "Max")
plt.plot(stats["min"], marker='.', linewidth = 1.0, label = "Min")
plt.fill_between(stats.index, stats["min"], stats["max"], color = "#aaaaaa")
ax = plt.gca()
plt.xlabel("Year")
plt.ylabel("Square Footage")
plt.yscale("log")
new_transform = mpt.blended_transform_factory(ax.transData, ax.transAxes)
plt.plot([1818, 1818], [0.0, 1.0], color = 'black', linewidth = 2.0, transform = new_transform)
plt.legend()

# %%
@ipywidgets.interact(window = (1, 10, 1))
def make_plot(window):
    df2 = stats.rolling(window = window)["mean"].mean()
    plt.plot(stats["mean"], marker = '.', linewidth = 0.5, alpha = 0.5)
    plt.plot(df2, marker = '.', linewidth = 1.5)
    plt.yscale("log")
# Out:
# interactive(children=(IntSlider(value=5, description='window', max=10, min=1), Output()), _dom_classes=('widget-interact',))

# %%
df.groupby("Year Acquired")["Square Footage"].sum().rolling(3).sum()
# Out:
# Year Acquired
# 1753.0          NaN
# 1802.0          NaN
# 1810.0       9673.0
# 1832.0     128473.0
# 1837.0     134335.0
# 1838.0     132312.0
# 1839.0      24064.0
# 1840.0      50680.0
# 1841.0      51926.0
# 1843.0      41074.0
# 1844.0       8244.0
# 1845.0      70834.0
# 1848.0      91226.0
# 1850.0      89405.0
# 1853.0     278559.0
# 1854.0     259407.0
# 1855.0     323294.0
# 1856.0      69044.0
# 1857.0      85028.0
# 1858.0      41241.0
# 1859.0      45338.0
# 1860.0      54631.0
# 1863.0      48059.0
# 1865.0     266706.0
# 1867.0     241989.0
# 1870.0     229058.0
# 1871.0      11967.0
# 1872.0      24167.0
# 1873.0      32303.0
# 1874.0      32500.0
#             ...
# 1990.0    4880971.0
# 1991.0    6048595.0
# 1992.0    4763505.0
# 1993.0    2906455.0
# 1994.0    1688265.0
# 1995.0    1665051.0
# 1996.0    2664644.0
# 1997.0    3339651.0
# 1998.0    3193649.0
# 1999.0    2206475.0
# 2000.0    2344598.0
# 2001.0    2943158.0
# 2002.0    3614851.0
# 2003.0    3407693.0
# 2004.0    2652990.0
# 2005.0    3111291.0
# 2006.0    2691372.0
# 2007.0    3111647.0
# 2008.0    1777459.0
# 2009.0    1415473.0
# 2010.0     798672.0
# 2011.0     791402.0
# 2012.0     781791.0
# 2013.0     794551.0
# 2014.0    1305896.0
# 2015.0    1360876.0
# 2016.0    1274230.0
# 2017.0     616652.0
# 2018.0     328719.0
# 2019.0      25400.0
# Name: Square Footage, Length: 171, dtype: float64
